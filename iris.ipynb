# %% [markdown]
# ## Anderson's/Fisher's Iris Data Set for analysing in Python
# by Nataliia Dragunova, 2024
# ***
# Records of 150 iris flowers, collected by Edgar Anderson in the Gaspé Peninsula of Quebec, Canada
#
# ![](iris.jpg)
#
# "The Iris flower, immortalized in Fisher's pioneering dataset, blooms as a symbol of scientific discovery and the elegant intersection of nature and data." ChatGPT
# ***
# ### Dataset Information
#
# **Anderson's/Fisher's Iris Dataset**
#
#
# Iris flower dataset (also known as Fisher’s or Anderson's Iris dataset) is actually a set of 150 rows which represents 3 classes of iris flowers with 50 in each. Two classes (species) of plant (Iris virginica and Iris versicolor) usually associate linearly together because they were collected and qualified by an American botanist Edgar Anderson in the same conditions (place, time etc), while class of Iris setosa is separable. Every flower was measured by 4 numerical features such as: Sepal Length, Sepal Width, Petal Length and Petal Width - it identifies 4 unique variables for every flower. This dataset is widely known for using in statistics and in machine learning as a practical task for studying and analytical purposes.
#
# **Interesting Facts**
#
#
#
# **Open Source articles**
#
# For more in-depth information on this dataset :
#
# Fisher,R.A. "The use of multiple measurements in taxonomic problems"
#       Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions
#       to Mathematical Statistics" (John Wiley, NY, 1950).
#
# Load the dataset:
#
# https://archive.ics.uci.edu/dataset/53/iris
#
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv

# %% [markdown]
# ### Dataset Typology
#
# For reviewing the Iris Dataset I use Python and a few libraries. I load a dataset in CSV format from [this sourse.]("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %%
# Load libraries
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the iris dataset from URL
iris_df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %% [markdown]
# **Variables**
#
# Dataset consists of 5 colummns that contain all relevant information about 150 Iris flowers.

# %%
# data set
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **There is only 1 nominal** (because no obvious natural ordering between 3 species) **categorical variable in the Iris Dataset :**
# - species (class) : Setosa, Versicolor, Virginica

# %%
# Count an iris population of every class ('species')
iris_df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **There are 4 continuous** (because length/width of petal/sepal don’t come in fixed, standard increments - they vary continuously) **numerical variables in the Iris Dataset :**
# - petal_length : iris petal length (cm)
# - petal_width : iris petal width (cm)
# - sepal_length : iris sepal length (cm)
# - sepal_width : iris sepal wid (cm)

# %%
# Continuous numerical variables in Iris Dataset: 

iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **Variables for Histograms**
#
# Histogram depicts the frequency distribution of variables in a dataset. And it is ideal for visualizing quantitative data or numerical data. Iris Dataset has 4 numerical variables (petal_length, petal_width, sepal_length, sepal_width) for creating histograms

# %%
from seaborn import pairplot

# Pair Plot
pairplot(iris_df, hue='species')
plt.show()

# %% [markdown]
# **Violin plot**

# %%
sns.set_theme(style="darkgrid")
df = sns.load_dataset('iris')

# Violin plot
sns.violinplot(x=df["species"], y=df["sepal_length"])
plt.show()

# %%
sns.set_theme(style="darkgrid")
df = sns.load_dataset('iris')

# Violin plot
sns.violinplot(x=df["species"], y=df["sepal_width"])
plt.show()

# %% [markdown]
# ### Dataset Analysing
#
# **Key Questions**
#
# The goal of creating an Iris dataset almost 90 years ago was to prove a clear classification of iris species(classes) depending on the physical parameters of flower parts. Then it was originally used in Fisher's paper in 1936 "The use of multiple measurements in taxonomic problems," where he introduced the concept of Linear Discriminant Analysis (LDA).
# The Key Question for the dataset can be to prove or disprove a certain classification of flowers by estimating the parameters (length/width of the petal/sepal) of each flower.

# %%
# Creating a scatter plot in seaborn 

sns.scatterplot(data= iris_df, x=df['petal_length'], y=df['petal_width'], hue =df['species'])

# Set labels and title
plt.xlabel('Petal length(cm)')
plt.ylabel('Petal width (cm)')
plt.title('Iris Petal length vs Petal Width')

plt.show()

# %%
# Creating a scatter plot in seaborn 

sns.scatterplot(data= iris_df, x=df['sepal_length'], y=df['sepal_width'], hue =df['species'])

# Set labels and title
plt.xlabel('Sepal length(cm)')
plt.ylabel('Sepal width (cm)')
plt.title('Iris Sepal length vs Sepal Width')

plt.show()

# %% [markdown]
# **Conclusion** (alternative)

# %% [markdown]
# ***
